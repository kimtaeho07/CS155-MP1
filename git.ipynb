# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Might need to change here depending on file location in your gdrive
# %cd /content/gdrive/MyDrive/Colab\ Notebooks/MP1/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/MP1

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/Colab Notebooks/MP1/.git/

# %%
# !git remote rm origin
# !git remote add origin https://kimtaeho07:Rlaxogh950707@github.com/kimtaeho07/CS155-MP1.git
# !git remote -v
# Out:
# origin	https://kimtaeho07:Rlaxogh950707@github.com/kimtaeho07/CS155-MP1.git (fetch)
# origin	https://kimtaeho07:Rlaxogh950707@github.com/kimtaeho07/CS155-MP1.git (push)

# %%
# Change your username stuff here
# !git config --global user.email "tkim7@caltech.edu"
# !git config --global user.name "kimtaeho07"

# %%
# !git add -u
# !git reset -- /content/gdrive/MyDrive/Colab\ Notebooks/MP1/git.ipynb # Don't upload git.ipynb

# Change message on commits here
# !git commit -m 'Second commit'
# Out:
# fatal: /content/gdrive/MyDrive/Colab Notebooks/MP1/git.ipynb: '/content/gdrive/MyDrive/Colab Notebooks/MP1/git.ipynb' is outside repository
# [master fe58c0d] Second commit

# %%
# !git pull origin master
# !git push origin master
# Out:
# From https://github.com/kimtaeho07/CS155-MP1
#  * branch            master     -> FETCH_HEAD
# CONFLICT (modify/delete): git.ipynb deleted in f2d931fe2ee2ca4d9db4d6943dbda3e92be948a4 and modified in HEAD. Version HEAD of git.ipynb left in tree.
# Automatic merge failed; fix conflicts and then commit the result.
# To https://github.com/kimtaeho07/CS155-MP1.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://kimtaeho07:Rlaxogh950707@github.com/kimtaeho07/CS155-MP1.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
